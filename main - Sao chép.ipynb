# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import TimeSeriesSplit
from keras.layers import LSTM, Dense, Dropout
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error
from keras.models import Sequential
from tensorflow.keras.utils import plot_model
import matplotlib.pyplot as plt
# Out:
# WARNING:tensorflow:From c:\Users\Admin\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
df = pd.read_excel("./alldata.xlsx")

# %%
print(df)
# Out:
#            Date    Price     Open     High      Low   Vol.  Change %  \
# 0    2010-07-18      0.1      0.0      0.1      0.1   0.08      0.00
# 1    2010-07-19      0.1      0.1      0.1      0.1   0.57      0.00
# 2    2010-07-20      0.1      0.1      0.1      0.1   0.26      0.00
# 3    2010-07-21      0.1      0.1      0.1      0.1   0.58      0.00
# 4    2010-07-22      0.1      0.1      0.1      0.1   2.16      0.00
# ...         ...      ...      ...      ...      ...    ...       ...
# 4932 2024-01-18  41292.7  42763.5  42908.0  40682.6  70.35     -3.45
# 4933 2024-01-19  41648.0  41293.8  42164.6  40305.4  72.64      0.86
# 4934 2024-01-20  41695.4  41647.6  41858.0  41449.5  22.27      0.11
# 4935 2024-01-21  41583.2  41695.4  41878.0  41504.5  16.11     -0.27
# 4936 2024-01-22  40825.8  41581.7  41684.9  40711.9  30.31     -1.82
#
#       FEDFUNDS       Gold
# 0         0.18  1204.7500
# 1         0.18  1190.2500
# 2         0.18  1181.5000
# 3         0.18  1191.2500
# 4         0.18  1187.0000
# ...        ...        ...
# 4932      5.33  2023.1038
# 4933      5.33  2029.6244
# 4934      5.33  2029.6244
# 4935      5.33  2029.6244
# 4936      5.33  2026.7500
#
# [4937 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4937 entries, 0 to 4936
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      4937 non-null   datetime64[ns]
#  1   Price     4937 non-null   float64
#  2   Open      4937 non-null   float64
#  3   High      4937 non-null   float64
#  4   Low       4937 non-null   float64
#  5   Vol.      4937 non-null   float64
#  6   Change %  4937 non-null   float64
#  7   FEDFUNDS  4937 non-null   float64
#  8   Gold      4937 non-null   float64
# dtypes: datetime64[ns](1), float64(8)
# memory usage: 347.3 KB

# %%
null_rows = df[df.isnull().any(axis=1)]

# Hiển thị kết quả
print("Các hàng có giá trị null:")
print(null_rows)
# Out:
# Các hàng có giá trị null:
# Empty DataFrame
# Columns: [Date, Price, Open, High, Low, Vol., Change %, FEDFUNDS, Gold]
# Index: []

# %%
df['Price'].plot()
# Out:
# <Axes: >

# %%
output = pd.DataFrame(df['Price'])
features = ['Open', 'High', 'Low', 'Vol.', 'Change %', 'FEDFUNDS', 'Gold']

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
feature_transform = scaler.fit_transform(df[features])
feature_transform = pd.DataFrame(columns=features, data=feature_transform, index=df.index)
print(feature_transform)
# Out:
#           Open      High       Low      Vol.  Change %  FEDFUNDS      Gold
# 0     0.000000  0.000000  0.000002  0.000080  0.145185  0.024621  0.145612
# 1     0.000001  0.000000  0.000002  0.000570  0.145185  0.024621  0.132004
# 2     0.000001  0.000000  0.000002  0.000260  0.145185  0.024621  0.123792
# 3     0.000001  0.000000  0.000002  0.000580  0.145185  0.024621  0.132942
# 4     0.000001  0.000000  0.000002  0.002161  0.145185  0.024621  0.128954
# ...        ...       ...       ...       ...       ...       ...       ...
# 4932  0.633264  0.621939  0.613291  0.070383  0.136429  1.000000  0.913659
# 4933  0.611500  0.611164  0.607605  0.072674  0.147367  1.000000  0.919779
# 4934  0.616739  0.606720  0.624852  0.022280  0.145464  1.000000  0.919779
# 4935  0.617447  0.607010  0.625681  0.016118  0.144499  1.000000  0.919779
# 4936  0.615763  0.604211  0.613733  0.030324  0.140566  1.000000  0.917081
#
# [4937 rows x 7 columns]

# %%
df_train = df.iloc[4907:]
df_demo = df.iloc[:4907]

print(df_train.shape)

print(df_train.shape)

# %%
#Splitting to Training set and Test set
timesplit= TimeSeriesSplit(n_splits=30)
for train_index, test_index in timesplit.split(df[features]):
        X_train, X_test = df[features][:len(train_index)], df[features][len(train_index): (len(train_index)+len(test_index))]
        y_train, y_test = output[:len(train_index)].values.ravel(), output[len(train_index): (len(train_index)+len(test_index))].values.ravel()

# %%
trainX =np.array(X_train)
testX =np.array(X_test)
X_train = trainX.reshape(X_train.shape[0], 1, X_train.shape[1])
X_test = testX.reshape(X_test.shape[0], 1, X_test.shape[1])

# %%
trainX.shape[1]
# Out:
# 7

# %%
lstm = Sequential()
lstm.add(LSTM(50, input_shape=(1, trainX.shape[1]), activation='relu', return_sequences=False))
lstm.add(Dense(1))
lstm.compile(loss='mean_absolute_percentage_error', optimizer='adam')
lstm.summary()
# Out:
# WARNING:tensorflow:From c:\Users\Admin\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\Admin\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50)                11600
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 11651 (45.51 KB)
# Trainable params: 11651 (45.51 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history=lstm.fit(X_train, y_train, epochs=100, batch_size=2, verbose=1, shuffle=False)
# Out:
# Epoch 1/100
# WARNING:tensorflow:From c:\Users\Admin\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 2389/2389 [==============================] - 4s 1ms/step - loss: 59.0462
# Epoch 2/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 516.3233
# Epoch 3/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 35.4009
# Epoch 4/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 22.2177
# Epoch 5/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 20.3746
# Epoch 6/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 20.8869
# Epoch 7/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 25.2703
# Epoch 8/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 29.7248
# Epoch 9/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 28.9917
# Epoch 10/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 23.2957
# Epoch 11/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 18.5700
# Epoch 12/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 19.8504
# Epoch 13/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 20.4441
# Epoch 14/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 24.4322
# Epoch 15/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 21.3364
# Epoch 16/100
# 2389/2389 [==============================] - 4s 2ms/step - loss: 31.7363
# Epoch 17/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 18.1974
# Epoch 18/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 17.5768
# Epoch 19/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 19.6841
# Epoch 20/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 19.7607
# Epoch 21/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 16.1820
# Epoch 22/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 19.6195
# Epoch 23/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 17.4767
# Epoch 24/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 16.8708
# Epoch 25/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 22.7751
# Epoch 26/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 16.6905
# Epoch 27/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 16.3050
# Epoch 28/100
# 2389/2389 [==============================] - 4s 2ms/step - loss: 14.9009
# Epoch 29/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 18.2368
# Epoch 30/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 18.2814
# Epoch 31/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 14.7289
# Epoch 32/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 16.4567
# Epoch 33/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 18.4053
# Epoch 34/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 19.7749
# Epoch 35/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 24.6191
# Epoch 36/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 16.7786
# Epoch 37/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 23.7134
# Epoch 38/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 15.5186
# Epoch 39/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 24.6859
# Epoch 40/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 16.9135
# Epoch 41/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 18.2790
# Epoch 42/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 15.3481
# Epoch 43/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 24.3479
# Epoch 44/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 19.2717
# Epoch 45/100
# 2389/2389 [==============================] - 2s 1ms/step - loss: 15.9975
# Epoch 46/100
# 2389/2389 [==============================] - 2s 1ms/step - loss: 17.9129
# Epoch 47/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 14.4376
# Epoch 48/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 23.7511
# Epoch 49/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 14.3486
# Epoch 50/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 14.0562
# Epoch 51/100
# 2389/2389 [==============================] - 2s 1ms/step - loss: 12.3982
# Epoch 52/100
# 2389/2389 [==============================] - 2s 1ms/step - loss: 15.1335
# Epoch 53/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 14.7793
# Epoch 54/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 24.7304
# Epoch 55/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 21.1302
# Epoch 56/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 12.9581
# Epoch 57/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 21.6127
# Epoch 58/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 14.4203
# Epoch 59/100
# 2389/2389 [==============================] - 2s 1ms/step - loss: 12.7640
# Epoch 60/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 14.0319
# Epoch 61/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 16.8428
# Epoch 62/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 13.2982
# Epoch 63/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 14.8351
# Epoch 64/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 14.3382
# Epoch 65/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 18.1625
# Epoch 66/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 12.0486
# Epoch 67/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 14.1668
# Epoch 68/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 11.8787
# Epoch 69/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 13.8822
# Epoch 70/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 17.7226
# Epoch 71/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 16.2983
# Epoch 72/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 18.3878
# Epoch 73/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 11.2226
# Epoch 74/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 16.2898
# Epoch 75/100
# 2389/2389 [==============================] - 2s 1ms/step - loss: 11.0436
# Epoch 76/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 12.1812
# Epoch 77/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 10.7749
# Epoch 78/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 10.3904
# Epoch 79/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 11.5779
# Epoch 80/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 11.2126
# Epoch 81/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 11.9569
# Epoch 82/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 11.1131
# Epoch 83/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 9.8777
# Epoch 84/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 11.2868
# Epoch 85/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 14.1164
# Epoch 86/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 14.9355
# Epoch 87/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 13.8522
# Epoch 88/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 12.8386
# Epoch 89/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 16.6719
# Epoch 90/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 11.5414
# Epoch 91/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 13.2308
# Epoch 92/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 13.6361
# Epoch 93/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 14.5760
# Epoch 94/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 9.6714
# Epoch 95/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 10.0160
# Epoch 96/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 11.6726
# Epoch 97/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 15.1474
# Epoch 98/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 17.5671
# Epoch 99/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 14.7247
# Epoch 100/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 13.0844

# %%
# In biểu đồ sự tiến triển của mô hình
import matplotlib.pyplot as plt
    
plt.plot(history.history['loss'], label='Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
y_pred= lstm.predict(X_test)
# Out:
# 5/5 [==============================] - 0s 1ms/step

# %%
#Predicted vs True Adj Close Value – LSTM
plt.plot(y_test, label='True Value')
plt.plot(y_pred, label='LSTM Value')
plt.title('Prediction by LSTM')
plt.xlabel('Time Scale')
plt.ylabel('Scaled USD')
plt.legend()
plt.show()

# %%
rmse = mean_squared_error(y_test,y_pred, squared=False)
mape = mean_absolute_percentage_error(y_test,y_pred)
print("RMSE = ", rmse)
print("MAPE = ", mape)
# Out:
# RMSE =  303.8001502989278
# MAPE =  0.005512719618371275
