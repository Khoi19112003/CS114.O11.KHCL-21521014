# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import TimeSeriesSplit
from keras.layers import LSTM, Dense, Dropout
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error
from keras.models import Sequential
from tensorflow.keras.utils import plot_model
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("./alldata.xlsx")

# %%
print(df)
# Out:
#            Date    Price     Open     High      Low   Vol.  Change %  \
# 0    2010-07-18      0.1      0.0      0.1      0.1   0.08      0.00
# 1    2010-07-19      0.1      0.1      0.1      0.1   0.57      0.00
# 2    2010-07-20      0.1      0.1      0.1      0.1   0.26      0.00
# 3    2010-07-21      0.1      0.1      0.1      0.1   0.58      0.00
# 4    2010-07-22      0.1      0.1      0.1      0.1   2.16      0.00
# ...         ...      ...      ...      ...      ...    ...       ...
# 4932 2024-01-18  41292.7  42763.5  42908.0  40682.6  70.35     -3.45
# 4933 2024-01-19  41648.0  41293.8  42164.6  40305.4  72.64      0.86
# 4934 2024-01-20  41695.4  41647.6  41858.0  41449.5  22.27      0.11
# 4935 2024-01-21  41583.2  41695.4  41878.0  41504.5  16.11     -0.27
# 4936 2024-01-22  40825.8  41581.7  41684.9  40711.9  30.31     -1.82
#
#       FEDFUNDS       Gold
# 0         0.18  1204.7500
# 1         0.18  1190.2500
# 2         0.18  1181.5000
# 3         0.18  1191.2500
# 4         0.18  1187.0000
# ...        ...        ...
# 4932      5.33  2023.1038
# 4933      5.33  2029.6244
# 4934      5.33  2029.6244
# 4935      5.33  2029.6244
# 4936      5.33  2026.7500
#
# [4937 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4937 entries, 0 to 4936
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      4937 non-null   datetime64[ns]
#  1   Price     4937 non-null   float64
#  2   Open      4937 non-null   float64
#  3   High      4937 non-null   float64
#  4   Low       4937 non-null   float64
#  5   Vol.      4937 non-null   float64
#  6   Change %  4937 non-null   float64
#  7   FEDFUNDS  4937 non-null   float64
#  8   Gold      4937 non-null   float64
# dtypes: datetime64[ns](1), float64(8)
# memory usage: 347.3 KB

# %%
null_rows = df[df.isnull().any(axis=1)]

# Hiển thị kết quả
print("Các hàng có giá trị null:")
print(null_rows)
# Out:
# Các hàng có giá trị null:
# Empty DataFrame
# Columns: [Date, Price, Open, High, Low, Vol., Change %, FEDFUNDS, Gold]
# Index: []

# %%
df['Price'].plot()
# Out:
# <Axes: >

# %%
output = pd.DataFrame(df['Price'])
features = ['Open', 'High', 'Low', 'Vol.', 'Change %', 'FEDFUNDS', 'Gold']

# %%
"""from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
feature_transform = scaler.fit_transform(df[features])
feature_transform = pd.DataFrame(columns=features, data=feature_transform, index=df.index)
print(feature_transform)"""
# Out:
# 'from sklearn.preprocessing import MinMaxScaler\nscaler = MinMaxScaler()\nfeature_transform = scaler.fit_transform(df[features])\nfeature_transform = pd.DataFrame(columns=features, data=feature_transform, index=df.index)\nprint(feature_transform)'

# %%
#Splitting to Training set and Test set
timesplit= TimeSeriesSplit(n_splits=30)
for train_index, test_index in timesplit.split(df[features]):
        X_train, X_test = df[features][:len(train_index)], df[features][len(train_index): (len(train_index)+len(test_index))]
        y_train, y_test = output[:len(train_index)].values.ravel(), output[len(train_index): (len(train_index)+len(test_index))].values.ravel()

# %%
trainX =np.array(X_train)
testX =np.array(X_test)
X_train = trainX.reshape(X_train.shape[0], 1, X_train.shape[1])
X_test = testX.reshape(X_test.shape[0], 1, X_test.shape[1])

# %%
trainX.shape[1]
# Out:
# 7

# %%
lstm = Sequential()
lstm.add(LSTM(50, input_shape=(1, trainX.shape[1]), activation='relu', return_sequences=False))
lstm.add(Dense(1))
lstm.compile(loss='mean_absolute_percentage_error', optimizer='adam')
lstm.summary()
# Out:
# Model: "sequential_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_19 (LSTM)              (None, 50)                11600
#
#  dense_19 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 11651 (45.51 KB)
# Trainable params: 11651 (45.51 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history=lstm.fit(X_train, y_train, epochs=100, batch_size=2, verbose=1, shuffle=False)
# Out:
# Epoch 1/100
# 2389/2389 [==============================] - 5s 1ms/step - loss: 82.3039
# Epoch 2/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 40.9534
# Epoch 3/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 22.8786
# Epoch 4/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 13.9978
# Epoch 5/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 13.1087
# Epoch 6/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 14.8020
# Epoch 7/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 14.0807
# Epoch 8/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 13.6129
# Epoch 9/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 13.2097
# Epoch 10/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 13.0229
# Epoch 11/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 11.9277
# Epoch 12/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 14.0262
# Epoch 13/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 12.9583
# Epoch 14/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 11.7663
# Epoch 15/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 13.3746
# Epoch 16/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 12.1482
# Epoch 17/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 11.2154
# Epoch 18/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 15.6010
# Epoch 19/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 16.0511
# Epoch 20/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 17.5630
# Epoch 21/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 18.8772
# Epoch 22/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 17.6704
# Epoch 23/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 14.8046
# Epoch 24/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 10.2677
# Epoch 25/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 9.5682
# Epoch 26/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 9.6807
# Epoch 27/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 11.4943
# Epoch 28/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 9.3894
# Epoch 29/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 11.5715
# Epoch 30/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 19.7894
# Epoch 31/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 15.0262
# Epoch 32/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 12.2025
# Epoch 33/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 14.3379
# Epoch 34/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 8.9711
# Epoch 35/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 14.1522
# Epoch 36/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 14.2606
# Epoch 37/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 16.2293
# Epoch 38/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 9.2833
# Epoch 39/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 8.5782
# Epoch 40/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 7.2362
# Epoch 41/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 7.1670
# Epoch 42/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 12.2665
# Epoch 43/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 13.6151
# Epoch 44/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 9.4036
# Epoch 45/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 7.6783
# Epoch 46/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 9.9719
# Epoch 47/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 13.2142
# Epoch 48/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 12.4279
# Epoch 49/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 9.5053
# Epoch 50/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 12.1776
# Epoch 51/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 9.1360
# Epoch 52/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 12.7605
# Epoch 53/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 8.9008
# Epoch 54/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 12.0549
# Epoch 55/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 10.3506
# Epoch 56/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 7.8830
# Epoch 57/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 5.9757
# Epoch 58/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 7.4589
# Epoch 59/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 12.3788
# Epoch 60/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 10.0278
# Epoch 61/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 9.6435
# Epoch 62/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 9.6328
# Epoch 63/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 8.3342
# Epoch 64/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 12.7120
# Epoch 65/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 9.0747
# Epoch 66/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 13.6536
# Epoch 67/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 10.3245
# Epoch 68/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 11.3782
# Epoch 69/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 9.5099
# Epoch 70/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 12.0420
# Epoch 71/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 14.1897
# Epoch 72/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 11.4426
# Epoch 73/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 30.6676
# Epoch 74/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 6.5665
# Epoch 75/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 4.8386
# Epoch 76/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 18.6633
# Epoch 77/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 5.4094
# Epoch 78/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 5.6679
# Epoch 79/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 5.0845
# Epoch 80/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 7.1634
# Epoch 81/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 5.4984
# Epoch 82/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 11.0742
# Epoch 83/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 7.3112
# Epoch 84/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 6.8460
# Epoch 85/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 5.0258
# Epoch 86/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 10.2891
# Epoch 87/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 8.3475
# Epoch 88/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 5.3682
# Epoch 89/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 14.8765
# Epoch 90/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 5.5117
# Epoch 91/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 8.8155
# Epoch 92/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 5.6092
# Epoch 93/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 4.9637
# Epoch 94/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 7.4233
# Epoch 95/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 4.6404
# Epoch 96/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 9.1529
# Epoch 97/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 5.6050
# Epoch 98/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 5.3859
# Epoch 99/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 4.8406
# Epoch 100/100
# 2389/2389 [==============================] - 3s 1ms/step - loss: 16.8063

# %%
# In biểu đồ sự tiến triển của mô hình
import matplotlib.pyplot as plt
    
plt.plot(history.history['loss'], label='Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
y_pred= lstm.predict(X_test)
# Out:
# 5/5 [==============================] - 0s 2ms/step

# %%
#Predicted vs True Adj Close Value – LSTM
plt.plot(y_test, label='True Value')
plt.plot(y_pred, label='LSTM Value')
plt.title('Prediction by LSTM')
plt.xlabel('Time Scale')
plt.ylabel('Scaled USD')
plt.legend()
plt.show()

# %%
rmse = mean_squared_error(y_test,y_pred, squared=False)
mape = mean_absolute_percentage_error(y_test,y_pred)
print("RMSE = ", rmse)
print("MAPE = ", mape)
# Out:
# RMSE =  315.77917031774086
# MAPE =  0.006285931798477769
